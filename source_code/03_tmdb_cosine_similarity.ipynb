# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import contractions
import json

# %%
movieDF = pd.read_csv('../data/processed/tmdb_4796.csv')

# %%
movieDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4796 entries, 0 to 4795
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    4796 non-null   int64
#  1   title                 4796 non-null   object
#  2   release_date          4796 non-null   object
#  3   original_language     4796 non-null   object
#  4   overview              4795 non-null   object
#  5   cast                  4796 non-null   object
#  6   crew                  4796 non-null   object
#  7   production_countries  4707 non-null   object
#  8   keywords              4523 non-null   object
#  9   tagline               4222 non-null   object
#  10  genres                4789 non-null   object
#  11  vote_average          4796 non-null   float64
#  12  vote_count            4796 non-null   int64
#  13  popularity            4796 non-null   float64
#  14  runtime               4796 non-null   int64
#  15  backdrop_path         4615 non-null   object
#  16  poster_path           4771 non-null   object
#  17  homepage              1772 non-null   object
# dtypes: float64(2), int64(3), object(13)
# memory usage: 674.6+ KB

# %%
movieDF.head(2)
# Out:
#       id                                     title release_date  \
# 0  19995                                    Avatar   2009-12-15
# 1    285  Pirates of the Caribbean: At World's End   2007-05-19
#
#   original_language                                           overview  \
# 0                en  In the 22nd century, a paraplegic Marine is di...
# 1                en  Captain Barbossa, long believed to be dead, ha...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
#
#                        production_countries  \
# 0  United States of America, United Kingdom
# 1                  United States of America
#
#                                             keywords  \
# 0  future, society, culture clash, space travel, ...
# 1  east india company, exotic island, strong woma...
#
#                                           tagline  \
# 0                     Enter the world of Pandora.
# 1  At the end of the world, the adventure begins.
#
#                                         genres  vote_average  vote_count  \
# 0  Action, Adventure, Fantasy, Science Fiction         7.573       29815
# 1                   Adventure, Fantasy, Action         7.239       13345
#
#    popularity  runtime                     backdrop_path  \
# 0      79.932      162  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg
# 1      81.883      169  /kPcHuPYqzkSo4bmPHtH82GaeEgX.jpg
#
#                         poster_path  \
# 0  /kyeqWdyUXW608qlYkRqosgbbJyK.jpg
# 1  /jGWpG4YhpQwVmjyHEGkxEkeRf0S.jpg
#
#                                             homepage
# 0               https://www.avatar.com/movies/avatar
# 1  https://movies.disney.com/pirates-of-the-carib...

# %%
### keywords, tagline 에 결측치가 많음
movieDF.isnull().sum()
# Out:
# id                         0
# title                      0
# release_date               0
# original_language          0
# overview                   1
# cast                       0
# crew                       0
# production_countries      89
# keywords                 273
# tagline                  574
# genres                     7
# vote_average               0
# vote_count                 0
# popularity                 0
# runtime                    0
# backdrop_path            181
# poster_path               25
# homepage                3024
# dtype: int64

# %%
movieDF[movieDF['genres'].isnull()]
# Out:
#           id                                              title release_date  \
# 4307  137955                                          Crowsnest   2012-09-07
# 4406  335874                                          Childless   2015-04-03
# 4497  331493                            Light from the Darkroom   2014-01-01
# 4564  328307  Rise of the Entrepreneur: The Search for a Bet...   2014-11-20
# 4650  320435                                          UnDivided   2013-02-01
# 4667  194588                   Short Cut to Nirvana: Kumbh Mela   2004-05-11
# 4709   38786  The Blood of My Brother: A Story of Death in Iraq   2005-11-25
#
#      original_language                                           overview  \
# 4307                en  In late summer of 2011, five young friends on ...
# 4406                en  Katherine is a typical teenager. Today's her f...
# 4497                en  Light in the Darkroom is the story of two best...
# 4564                en  The world is changing faster than ever. Techno...
# 4650                en  UnDivided documents the true story of how a su...
# 4667                en  Every 12 years over 70 million pilgrims gather...
# 4709                en  THE BLOOD OF MY BROTHER goes behind the scenes...
#
#                                                    cast  \
# 4307                                                 []
# 4406  [{"cast_id": 1, "character": "", "credit_id": ...
# 4497                                                 []
# 4564                                                 []
# 4650                                                 []
# 4667                                                 []
# 4709                                                 []
#
#                                                    crew  \
# 4307                                                 []
# 4406  [{"credit_id": "55575bb49251411e62005cfd", "de...
# 4497                                                 []
# 4564                                                 []
# 4650                                                 []
# 4667                                                 []
# 4709                                                 []
#
#                   production_countries         keywords tagline genres  \
# 4307                            Canada    found footage     NaN    NaN
# 4406          United States of America              NaN     NaN    NaN
# 4497  Panama, United States of America  faith, massacre     NaN    NaN
# 4564                               NaN              NaN     NaN    NaN
# 4650          United States of America              NaN     NaN    NaN
# 4667                               NaN              NaN     NaN    NaN
# 4709                               NaN              NaN     NaN    NaN
#
#       vote_average  vote_count  popularity  runtime  \
# 4307         4.984          31       3.659       84
# 4406         4.500           2       0.939       90
# 4497         0.000           0       1.192       90
# 4564         8.000           1       0.600        0
# 4650         0.000           0       0.600        0
# 4667         0.000           0       0.600       85
# 4709         5.700           3       0.600       90
#
#                          backdrop_path                       poster_path  \
# 4307                               NaN  /g2swX9YGaIq1dpGr7gva8DGnWe4.jpg
# 4406  /wzP9z4BCdb6sNkntTQ85688DVXw.jpg  /A3xnS8K4II7puaFO8Cwc5MubuRU.jpg
# 4497  /exRCs4v31yh5CENBUo45g4fa9eX.jpg  /1bWVwd3MIgMhLgAVKEPptzms29i.jpg
# 4564                               NaN                               NaN
# 4650                               NaN                               NaN
# 4667                               NaN                               NaN
# 4709                               NaN                               NaN
#
#                                    homepage
# 4307                                    NaN
# 4406  http://www.sealionfilms.com/childless
# 4497                                    NaN
# 4564                                    NaN
# 4650                                    NaN
# 4667                                    NaN
# 4709                                    NaN

# %% [markdown]
# ### (1) 줄거리(overview) 기반 코사인 유사도 행렬 생성

# %% [markdown]
# ##### 결측치 전처리

# %%
### overview 컬럼의 결측치 유무 조사 (1개 존재)
movieDF['overview'].isnull().sum()
# Out:
# 1

# %%
### 결측값을 빈 문자열 값으로 대체
movieDF['overview'] = movieDF['overview'].fillna('')

# %%
### 결측치 제거 확인
movieDF['overview'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ##### 영어 축약어 전처리

# %%
### 예시 문장
movieDF.loc[6, 'overview']
# Out:
# "When the kingdom's most wanted-and most charming-bandit Flynn Rider hides out in a mysterious tower, he's taken hostage by Rapunzel, a beautiful and feisty tower-bound teen with 70 feet of magical, golden hair. Flynn's curious captor, who's looking for her ticket out of the tower where she's been locked away for years, strikes a deal with the handsome thief and the unlikely duo sets off on an action-packed escapade, complete with a super-cop horse, an over-protective chameleon and a gruff gang of pub thugs."

# %%
### contractions 라이브러리를 사용해 축약어 확장 실행
movieDF['overview'] = movieDF['overview'].apply(lambda x: contractions.fix(x))

# %%
### 전처리 결과 확인
movieDF.loc[6, 'overview']
# Out:
# "When the kingdom's most wanted-and most charming-bandit Flynn Rider hides out in a mysterious tower, he is taken hostage by Rapunzel, a beautiful and feisty tower-bound teen with 70 feet of magical, golden hair. Flynn's curious captor, who is looking for her ticket out of the tower where she is been locked away for years, strikes a deal with the handsome thief and the unlikely duo sets off on an action-packed escapade, complete with a super-cop horse, an over-protective chameleon and a gruff gang of pub thugs."

# %%
### TF-IDF 행렬 생성 (=> 19823 단어 존재)
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(movieDF['overview']) # scipy.sparse._csr.csr_matrix
print(f'TF-IDF 행렬의 크기(shape) : {tfidf_matrix.shape}')
# Out:
# TF-IDF 행렬의 크기(shape) : (4796, 19823)

# %%
### 메모리 부족 주의 !!! (MemoryError 주의)
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)  # ndarray
print(f'코사인 유사도 연산 결과 : {cosine_sim.shape}')
# Out:
# 코사인 유사도 연산 결과 : (4796, 4796)

# %%
### 영화제목 -> 해당 인덱스 (딕셔너리)
title_to_index = dict(zip(movieDF['title'], movieDF.index))

# %%
def get_recommendations(title, cosine_sim, get_indices=False):
    ### 선택한 영화의 제목으로부터 해당 영화의 인덱스를 받아온다.
    idx = title_to_index[title]
    
    ### 해당 영화와 모든 영화와의 유사도를 가져온다.
    sim_scores = list(enumerate(cosine_sim[idx]))
    
    ### 유사도에 따라 영화들을 정렬한다.
    sim_scores.sort(key=lambda x: x[1], reverse=True)
    
    ### 가장 유사한 10개의 영화를 추출한다.
    sim_scores = sim_scores[1:11]
    
    ### 가장 유사한 10개 영화의 인덱스를 얻는다.
    movie_indices = [x[0] for x in sim_scores]
    
    if get_indices:
        ### 가장 유사한 10개 영화의 인덱스를 반환한다.
        return movie_indices
    else: 
        ### 가장 유사한 10개 영화의 제목을 리턴한다.
        return movieDF['title'].iloc[movie_indices]

# %%
get_recommendations('The Dark Knight Rises', cosine_sim)
# Out:
# 65                              The Dark Knight
# 210                              Batman & Robin
# 299                              Batman Forever
# 1359                                     Batman
# 3848    Batman: The Dark Knight Returns, Part 2
# 119                               Batman Begins
# 2507                                  Slow Burn
# 9            Batman v Superman: Dawn of Justice
# 1181                                        JFK
# 1349                      Ghosts of Mississippi
# Name: title, dtype: object

# %%
### 코사인 유사도 행렬(ndarray)을 csv 파일로 저장 (548MB)
# np.savetxt('../data/processed/cosine_similarity1_4796.csv', cosine_sim, delimiter=',')

# %%
### 코사인 유사도 행렬(ndarray)을 npy 파일로 저장 (175MB)
np.save('../data/processed/cosine_similarity1_4796.npy', cosine_sim)

# %% [markdown]
# ### (2) 출연진, 연출진 기반 코사인 유사도 행렬 생성
# - 일반적으로 고려하는 대상 : 출연진(최대 3명), 감독(모두), 각본가(모두), 제작자(최대 3명)
# - 출연진 정보는 중요도 순으로 저장되어 있음

# %%
### 각 딕셔너리 리스트를 DataFrame으로 바꾸는 방법 (ast.literal_eval 함수도 비슷한 기능)
def str_to_df(input_str):
    """ 문자열으로 저장된 딕셔너리 리스트를 DataFrame으로 변환한 결과를 반환 """
    dict_list = json.loads(input_str)   # 속성명이 큰따옴표("")로 둘러싸여 있을 때만 작동
    castDF = pd.DataFrame(dict_list)
    return castDF

# %%
### 출연진 정보 예시
str_to_df(movieDF.loc[0, 'cast'])
# Out:
#     cast_id                       character                 credit_id  gender  \
# 0       242                      Jake Sully  5602a8a7c3a3685532001c9a       2
# 1         3                         Neytiri  52fe48009251416c750ac9cb       1
# 2        25             Dr. Grace Augustine  52fe48009251416c750aca39       1
# 3         4                   Col. Quaritch  52fe48009251416c750ac9cf       2
# 4         5                    Trudy Chacon  52fe48009251416c750ac9d3       1
# ..      ...                             ...                       ...     ...
# 78       98      Female Marine (uncredited)  52fe48019251416c750acb5f       0
# 79       99  Ikran Clan Leader (uncredited)  52fe48019251416c750acb63       1
# 80      100          Geologist (uncredited)  52fe48019251416c750acb67       0
# 81      101              Na'vi (uncredited)  52fe48019251416c750acb6b       0
# 82      102      Ambient Room Tech / Troupe  52fe48019251416c750acb6f       1
#
#          id                name  order
# 0     65731     Sam Worthington      0
# 1      8691         Zoe Saldana      1
# 2     10205    Sigourney Weaver      2
# 3     32747        Stephen Lang      3
# 4     17647  Michelle Rodriguez      4
# ..      ...                 ...    ...
# 78  1207291        Jodie Taylor     78
# 79  1186027  Alicia Vela-Bailey     79
# 80  1207292   Richard Whiteside     80
# 81   103259         Nikie Zambo     81
# 82    42286        Julene Renee     82
#
# [83 rows x 7 columns]

# %%
### cast 정보가 3명도 안 되는 영화가 있는지 확인 (=> 꽤 존재)
for i in range(4796):
    s = str_to_df(movieDF.loc[i, 'cast']).shape
    if s[0] < 3:
        print(f'{i} 번째 cast shape : {s}')
# Out:
# 1730 번째 cast shape : (2, 7)
# 2601 번째 cast shape : (0, 0)
# 3222 번째 cast shape : (1, 7)
# 3388 번째 cast shape : (2, 7)
# 3467 번째 cast shape : (2, 7)
# 3665 번째 cast shape : (0, 0)
# 3763 번째 cast shape : (1, 7)
# 3891 번째 cast shape : (1, 7)
# 3985 번째 cast shape : (0, 0)
# 4002 번째 cast shape : (0, 0)
# 4061 번째 cast shape : (0, 0)
# 4098 번째 cast shape : (2, 7)
# 4111 번째 cast shape : (0, 0)
# 4133 번째 cast shape : (1, 7)
# 4240 번째 cast shape : (0, 0)
# 4298 번째 cast shape : (0, 0)
# 4307 번째 cast shape : (0, 0)
# 4315 번째 cast shape : (0, 0)
# 4321 번째 cast shape : (1, 7)
# 4380 번째 cast shape : (2, 7)
# 4394 번째 cast shape : (0, 0)
# 4424 번째 cast shape : (0, 0)
# 4451 번째 cast shape : (0, 0)
# 4461 번째 cast shape : (1, 7)
# 4464 번째 cast shape : (2, 7)
# 4484 번째 cast shape : (0, 0)
# 4497 번째 cast shape : (0, 0)
# 4501 번째 cast shape : (0, 0)
# 4510 번째 cast shape : (0, 0)
# 4519 번째 cast shape : (1, 7)
# 4533 번째 cast shape : (2, 7)
# 4543 번째 cast shape : (0, 0)
# 4546 번째 cast shape : (0, 0)
# 4555 번째 cast shape : (0, 0)
# 4557 번째 cast shape : (0, 0)
# 4559 번째 cast shape : (0, 0)
# 4564 번째 cast shape : (0, 0)
# 4567 번째 cast shape : (2, 7)
# 4574 번째 cast shape : (0, 0)
# 4576 번째 cast shape : (0, 0)
# 4582 번째 cast shape : (0, 0)
# 4590 번째 cast shape : (1, 7)
# 4599 번째 cast shape : (1, 7)
# 4609 번째 cast shape : (0, 0)
# 4610 번째 cast shape : (0, 0)
# 4626 번째 cast shape : (0, 0)
# 4631 번째 cast shape : (0, 0)
# 4650 번째 cast shape : (0, 0)
# 4651 번째 cast shape : (2, 7)
# 4667 번째 cast shape : (0, 0)
# 4672 번째 cast shape : (0, 0)
# 4678 번째 cast shape : (0, 0)
# 4682 번째 cast shape : (0, 0)
# 4691 번째 cast shape : (0, 0)
# 4703 번째 cast shape : (0, 0)
# 4705 번째 cast shape : (0, 0)
# 4709 번째 cast shape : (0, 0)
# 4730 번째 cast shape : (0, 0)
# 4748 번째 cast shape : (0, 0)
# 4750 번째 cast shape : (0, 0)
# 4772 번째 cast shape : (2, 7)
# 4775 번째 cast shape : (1, 7)
# 4790 번째 cast shape : (0, 0)

# %%
def get_casts(x: pd.Series):
    ### x는 movieDF의 한 행(Series)
    if not isinstance(x, pd.Series):
        return ""
    
    castDF = str_to_df(x['cast'])
    castnum = castDF.shape[0]
    
    if castnum >= 3:
        nameList = [name.lower() for name in castDF['name'].head(3)]
        nameList = [name.replace(" ", "") for name in nameList]
        return " ".join(nameList)
    elif castnum > 0:
        nameList = [name.lower() for name in castDF['name']]
        nameList = [name.replace(" ", "") for name in nameList]
        return " ".join(nameList)
    return ""

# %%
get_casts(movieDF.iloc[0])
# Out:
# 'samworthington zoesaldana sigourneyweaver'

# %%
get_casts(movieDF.iloc[1730])
# Out:
# 'philippelabro jacquesperrin'

# %%
### 연출진 정보 예시
str_to_df(movieDF.loc[0, 'crew'])
# Out:
#                     credit_id  department  gender       id  \
# 0    52fe48009251416c750aca23     Editing       0     1721
# 1    539c47ecc3a36810e3001f87         Art       2      496
# 2    54491c89c3a3680fb4001cf7       Sound       0      900
# 3    54491cb70e0a267480001bd0       Sound       0      900
# 4    539c4a4cc3a36810c9002101  Production       1     1262
# ..                        ...         ...     ...      ...
# 148  5592b2c3c3a36869e800003c        Crew       0  1483231
# 149  5592b317c3a36877470012af        Crew       0  1483232
# 150  5592b345c3a36877470012bb        Crew       0  1483233
# 151  5592b37cc3a368775100113b        Crew       0  1483234
# 152  573c8e2f9251413f5d000094        Crew       1  1621932
#
#                           job               name
# 0                      Editor  Stephen E. Rivkin
# 1           Production Design        Rick Carter
# 2              Sound Designer  Christopher Boyes
# 3    Supervising Sound Editor  Christopher Boyes
# 4                     Casting          Mali Finn
# ..                        ...                ...
# 148             CG Supervisor   Philippe Rebours
# 149             CG Supervisor  Michael Takarangi
# 150             CG Supervisor    David Weitzberg
# 151             CG Supervisor          Ben White
# 152                    Stunts         Min Windle
#
# [153 rows x 6 columns]

# %%
### 단계 : writer, script -> screenplay
### 추출대상 : Director, Writer, Screenplay, Producer, Executive Producer
### (Director of Photography, Original Music Composer, Production Design)
temp = str_to_df(movieDF.loc[0, 'crew'])
temp['job'].unique()
# Out:
# array(['Editor', 'Production Design', 'Sound Designer',
#        'Supervising Sound Editor', 'Casting', 'Original Music Composer',
#        'Director', 'Writer', 'Producer', 'Screenplay', 'Art Direction',
#        'Visual Effects Producer', 'Supervising Art Director',
#        'Music Editor', 'Sound Effects Editor', 'Foley', 'Costume Design',
#        'Set Decoration', 'Set Designer', 'Executive Producer',
#        'Director of Photography', 'Stunts', 'Makeup Artist',
#        'Hairstylist', 'Camera Operator', 'Visual Effects Supervisor',
#        'Visual Effects Editor', 'Dialect Coach', 'Motion Capture Artist',
#        'Stunt Coordinator', 'Steadicam Operator',
#        'Makeup Department Head', 'Post Production Supervisor',
#        'Costume Supervisor', 'Dialogue Editor',
#        'Transportation Coordinator', 'Art Department Coordinator',
#        'Assistant Art Director', 'Construction Coordinator',
#        'Sound Re-Recording Mixer', 'Choreographer', 'CG Supervisor',
#        'Digital Intermediate', 'Production Supervisor',
#        'Production Manager', 'Special Effects Coordinator',
#        'Best Boy Electric', 'Still Photographer', 'Lighting Technician',
#        'Animation Director', 'Set Costumer', 'Publicist',
#        'Conceptual Design', 'Visual Effects Art Director', 'Modeling',
#        'Art Department Manager', 'Lighting Artist'], dtype=object)

# %%
### crew 정보가 3명도 안 되는 영화가 있는지 확인 (=> 꽤 존재)
for i in range(4796):
    s = str_to_df(movieDF.loc[i, 'crew']).shape
    if s[0] < 3:
        print(f'{i} 번째 crew shape : {s}')
# Out:
# 761 번째 crew shape : (2, 6)
# 967 번째 crew shape : (2, 6)
# 1011 번째 crew shape : (1, 6)
# 1128 번째 crew shape : (2, 6)
# 1247 번째 crew shape : (2, 6)
# 1306 번째 crew shape : (2, 6)
# 1349 번째 crew shape : (2, 6)
# 1360 번째 crew shape : (2, 6)
# 1403 번째 crew shape : (2, 6)
# 1600 번째 crew shape : (2, 6)
# 1624 번째 crew shape : (1, 6)
# 1636 번째 crew shape : (2, 6)
# 1706 번째 crew shape : (2, 6)
# 1721 번째 crew shape : (2, 6)
# 1734 번째 crew shape : (2, 6)
# 1746 번째 crew shape : (2, 6)
# 1747 번째 crew shape : (2, 6)
# 1760 번째 crew shape : (2, 6)
# 1797 번째 crew shape : (2, 6)
# 1807 번째 crew shape : (2, 6)
# 1863 번째 crew shape : (2, 6)
# 1937 번째 crew shape : (1, 6)
# 1939 번째 crew shape : (2, 6)
# 2001 번째 crew shape : (2, 6)
# 2005 번째 crew shape : (1, 6)
# 2020 번째 crew shape : (2, 6)
# 2044 번째 crew shape : (1, 6)
# 2058 번째 crew shape : (2, 6)
# 2095 번째 crew shape : (2, 6)
# 2107 번째 crew shape : (2, 6)
# 2173 번째 crew shape : (2, 6)
# 2174 번째 crew shape : (1, 6)
# 2176 번째 crew shape : (2, 6)
# 2191 번째 crew shape : (2, 6)
# 2209 번째 crew shape : (2, 6)
# 2222 번째 crew shape : (2, 6)
# 2228 번째 crew shape : (2, 6)
# 2254 번째 crew shape : (2, 6)
# 2259 번째 crew shape : (1, 6)
# 2268 번째 crew shape : (1, 6)
# 2287 번째 crew shape : (2, 6)
# 2292 번째 crew shape : (1, 6)
# 2303 번째 crew shape : (1, 6)
# 2364 번째 crew shape : (1, 6)
# 2367 번째 crew shape : (1, 6)
# 2374 번째 crew shape : (1, 6)
# 2420 번째 crew shape : (2, 6)
# 2423 번째 crew shape : (2, 6)
# 2431 번째 crew shape : (2, 6)
# 2472 번째 crew shape : (1, 6)
# 2478 번째 crew shape : (2, 6)
# 2498 번째 crew shape : (1, 6)
# 2504 번째 crew shape : (2, 6)
# 2505 번째 crew shape : (2, 6)
# 2506 번째 crew shape : (1, 6)
# 2531 번째 crew shape : (2, 6)
# 2577 번째 crew shape : (1, 6)
# 2595 번째 crew shape : (2, 6)
# 2601 번째 crew shape : (1, 6)
# 2614 번째 crew shape : (1, 6)
# 2622 번째 crew shape : (2, 6)
# 2645 번째 crew shape : (2, 6)
# 2649 번째 crew shape : (2, 6)
# 2650 번째 crew shape : (2, 6)
# 2656 번째 crew shape : (2, 6)
# 2657 번째 crew shape : (1, 6)
# 2662 번째 crew shape : (2, 6)
# 2682 번째 crew shape : (1, 6)
# 2688 번째 crew shape : (1, 6)
# 2704 번째 crew shape : (2, 6)
# 2714 번째 crew shape : (2, 6)
# 2722 번째 crew shape : (2, 6)
# 2727 번째 crew shape : (2, 6)
# 2728 번째 crew shape : (2, 6)
# 2744 번째 crew shape : (2, 6)
# 2753 번째 crew shape : (2, 6)
# 2758 번째 crew shape : (2, 6)
# 2763 번째 crew shape : (2, 6)
# 2776 번째 crew shape : (2, 6)
# 2799 번째 crew shape : (2, 6)
# 2800 번째 crew shape : (2, 6)
# 2803 번째 crew shape : (2, 6)
# 2847 번째 crew shape : (1, 6)
# 2853 번째 crew shape : (2, 6)
# 2872 번째 crew shape : (2, 6)
# 2875 번째 crew shape : (1, 6)
# 2898 번째 crew shape : (1, 6)
# 2905 번째 crew shape : (2, 6)
# 2932 번째 crew shape : (2, 6)
# 2968 번째 crew shape : (2, 6)
# 2972 번째 crew shape : (2, 6)
# 3007 번째 crew shape : (2, 6)
# 3021 번째 crew shape : (2, 6)
# 3040 번째 crew shape : (2, 6)
# 3042 번째 crew shape : (2, 6)
# 3058 번째 crew shape : (2, 6)
# 3062 번째 crew shape : (2, 6)
# 3078 번째 crew shape : (2, 6)
# 3085 번째 crew shape : (2, 6)
# 3088 번째 crew shape : (1, 6)
# 3091 번째 crew shape : (2, 6)
# 3104 번째 crew shape : (2, 6)
# 3106 번째 crew shape : (2, 6)
# 3111 번째 crew shape : (1, 6)
# 3115 번째 crew shape : (1, 6)
# 3116 번째 crew shape : (2, 6)
# 3117 번째 crew shape : (2, 6)
# 3120 번째 crew shape : (2, 6)
# 3134 번째 crew shape : (1, 6)
# 3146 번째 crew shape : (2, 6)
# 3153 번째 crew shape : (2, 6)
# 3163 번째 crew shape : (2, 6)
# 3165 번째 crew shape : (2, 6)
# 3184 번째 crew shape : (1, 6)
# 3185 번째 crew shape : (2, 6)
# 3194 번째 crew shape : (1, 6)
# 3218 번째 crew shape : (2, 6)
# 3239 번째 crew shape : (1, 6)
# 3241 번째 crew shape : (2, 6)
# 3262 번째 crew shape : (1, 6)
# 3273 번째 crew shape : (2, 6)
# 3284 번째 crew shape : (1, 6)
# 3291 번째 crew shape : (2, 6)
# 3294 번째 crew shape : (1, 6)
# 3304 번째 crew shape : (2, 6)
# 3313 번째 crew shape : (1, 6)
# 3314 번째 crew shape : (2, 6)
# 3315 번째 crew shape : (1, 6)
# 3320 번째 crew shape : (2, 6)
# 3322 번째 crew shape : (2, 6)
# 3369 번째 crew shape : (2, 6)
# 3371 번째 crew shape : (2, 6)
# 3373 번째 crew shape : (1, 6)
# 3378 번째 crew shape : (1, 6)
# 3380 번째 crew shape : (2, 6)
# 3385 번째 crew shape : (1, 6)
# 3389 번째 crew shape : (1, 6)
# 3399 번째 crew shape : (1, 6)
# 3408 번째 crew shape : (2, 6)
# 3411 번째 crew shape : (2, 6)
# 3412 번째 crew shape : (2, 6)
# 3415 번째 crew shape : (2, 6)
# 3428 번째 crew shape : (1, 6)
# 3448 번째 crew shape : (1, 6)
# 3474 번째 crew shape : (1, 6)
# 3485 번째 crew shape : (2, 6)
# 3493 번째 crew shape : (2, 6)
# 3495 번째 crew shape : (2, 6)
# 3499 번째 crew shape : (2, 6)
# 3502 번째 crew shape : (2, 6)
# 3512 번째 crew shape : (2, 6)
# 3516 번째 crew shape : (1, 6)
# 3520 번째 crew shape : (2, 6)
# 3529 번째 crew shape : (2, 6)
# 3580 번째 crew shape : (2, 6)
# 3586 번째 crew shape : (2, 6)
# 3605 번째 crew shape : (1, 6)
# 3620 번째 crew shape : (2, 6)
# 3644 번째 crew shape : (2, 6)
# 3656 번째 crew shape : (0, 0)
# 3665 번째 crew shape : (0, 0)
# 3669 번째 crew shape : (2, 6)
# 3677 번째 crew shape : (2, 6)
# 3697 번째 crew shape : (1, 6)
# 3702 번째 crew shape : (1, 6)
# 3707 번째 crew shape : (2, 6)
# 3713 번째 crew shape : (2, 6)
# 3718 번째 crew shape : (1, 6)
# 3739 번째 crew shape : (2, 6)
# 3750 번째 crew shape : (2, 6)
# 3751 번째 crew shape : (2, 6)
# 3755 번째 crew shape : (1, 6)
# 3763 번째 crew shape : (1, 6)
# 3766 번째 crew shape : (2, 6)
# 3781 번째 crew shape : (2, 6)
# 3786 번째 crew shape : (2, 6)
# 3788 번째 crew shape : (2, 6)
# 3798 번째 crew shape : (2, 6)
# 3803 번째 crew shape : (1, 6)
# 3804 번째 crew shape : (2, 6)
# 3821 번째 crew shape : (2, 6)
# 3841 번째 crew shape : (1, 6)
# 3842 번째 crew shape : (2, 6)
# 3845 번째 crew shape : (2, 6)
# 3857 번째 crew shape : (1, 6)
# 3898 번째 crew shape : (2, 6)
# 3905 번째 crew shape : (2, 6)
# 3909 번째 crew shape : (2, 6)
# 3911 번째 crew shape : (2, 6)
# 3915 번째 crew shape : (2, 6)
# 3916 번째 crew shape : (1, 6)
# 3919 번째 crew shape : (2, 6)
# 3924 번째 crew shape : (2, 6)
# 3939 번째 crew shape : (1, 6)
# 3941 번째 crew shape : (2, 6)
# 3950 번째 crew shape : (1, 6)
# 3957 번째 crew shape : (2, 6)
# 3970 번째 crew shape : (0, 0)
# 3974 번째 crew shape : (2, 6)
# 3975 번째 crew shape : (2, 6)
# 3981 번째 crew shape : (2, 6)
# 3985 번째 crew shape : (1, 6)
# 4000 번째 crew shape : (2, 6)
# 4018 번째 crew shape : (2, 6)
# 4019 번째 crew shape : (2, 6)
# 4020 번째 crew shape : (2, 6)
# 4027 번째 crew shape : (2, 6)
# 4030 번째 crew shape : (2, 6)
# 4037 번째 crew shape : (1, 6)
# 4038 번째 crew shape : (2, 6)
# 4049 번째 crew shape : (2, 6)
# 4051 번째 crew shape : (2, 6)
# 4052 번째 crew shape : (2, 6)
# 4053 번째 crew shape : (2, 6)
# 4061 번째 crew shape : (0, 0)
# 4095 번째 crew shape : (2, 6)
# 4098 번째 crew shape : (0, 0)
# 4099 번째 crew shape : (2, 6)
# 4101 번째 crew shape : (1, 6)
# 4105 번째 crew shape : (1, 6)
# 4106 번째 crew shape : (2, 6)
# 4111 번째 crew shape : (0, 0)
# 4113 번째 crew shape : (1, 6)
# 4116 번째 crew shape : (0, 0)
# 4120 번째 crew shape : (2, 6)
# 4128 번째 crew shape : (2, 6)
# 4132 번째 crew shape : (2, 6)
# 4133 번째 crew shape : (1, 6)
# 4136 번째 crew shape : (2, 6)
# 4139 번째 crew shape : (2, 6)
# 4142 번째 crew shape : (2, 6)
# 4149 번째 crew shape : (2, 6)
# 4152 번째 crew shape : (2, 6)
# 4161 번째 crew shape : (2, 6)
# 4171 번째 crew shape : (1, 6)
# 4173 번째 crew shape : (2, 6)
# 4174 번째 crew shape : (1, 6)
# 4175 번째 crew shape : (2, 6)
# 4184 번째 crew shape : (2, 6)
# 4196 번째 crew shape : (2, 6)
# 4197 번째 crew shape : (2, 6)
# 4198 번째 crew shape : (2, 6)
# 4203 번째 crew shape : (2, 6)
# 4215 번째 crew shape : (2, 6)
# 4220 번째 crew shape : (1, 6)
# 4221 번째 crew shape : (2, 6)
# 4226 번째 crew shape : (1, 6)
# 4228 번째 crew shape : (2, 6)
# 4229 번째 crew shape : (1, 6)
# 4234 번째 crew shape : (1, 6)
# 4237 번째 crew shape : (2, 6)
# 4240 번째 crew shape : (0, 0)
# 4244 번째 crew shape : (2, 6)
# 4245 번째 crew shape : (2, 6)
# 4246 번째 crew shape : (2, 6)
# 4251 번째 crew shape : (2, 6)
# 4262 번째 crew shape : (2, 6)
# 4265 번째 crew shape : (2, 6)
# 4266 번째 crew shape : (1, 6)
# 4270 번째 crew shape : (2, 6)
# 4278 번째 crew shape : (2, 6)
# 4279 번째 crew shape : (1, 6)
# 4286 번째 crew shape : (2, 6)
# 4291 번째 crew shape : (1, 6)
# 4298 번째 crew shape : (0, 0)
# 4299 번째 crew shape : (1, 6)
# 4300 번째 crew shape : (1, 6)
# 4303 번째 crew shape : (1, 6)
# 4306 번째 crew shape : (2, 6)
# 4307 번째 crew shape : (0, 0)
# 4311 번째 crew shape : (1, 6)
# 4312 번째 crew shape : (2, 6)
# 4314 번째 crew shape : (1, 6)
# 4315 번째 crew shape : (0, 0)
# 4317 번째 crew shape : (1, 6)
# 4321 번째 crew shape : (1, 6)
# 4323 번째 crew shape : (2, 6)
# 4351 번째 crew shape : (2, 6)
# 4356 번째 crew shape : (1, 6)
# 4359 번째 crew shape : (2, 6)
# 4362 번째 crew shape : (1, 6)
# 4363 번째 crew shape : (2, 6)
# 4366 번째 crew shape : (2, 6)
# 4367 번째 crew shape : (1, 6)
# 4368 번째 crew shape : (2, 6)
# 4377 번째 crew shape : (2, 6)
# 4378 번째 crew shape : (1, 6)
# 4382 번째 crew shape : (1, 6)
# 4387 번째 crew shape : (2, 6)
# 4388 번째 crew shape : (2, 6)
# 4389 번째 crew shape : (2, 6)
# 4390 번째 crew shape : (2, 6)
# 4393 번째 crew shape : (1, 6)
# 4394 번째 crew shape : (0, 0)
# 4398 번째 crew shape : (0, 0)
# 4400 번째 crew shape : (2, 6)
# 4404 번째 crew shape : (1, 6)
# 4406 번째 crew shape : (2, 6)
# 4409 번째 crew shape : (2, 6)
# 4415 번째 crew shape : (2, 6)
# 4416 번째 crew shape : (2, 6)
# 4419 번째 crew shape : (1, 6)
# 4423 번째 crew shape : (2, 6)
# 4424 번째 crew shape : (1, 6)
# 4431 번째 crew shape : (2, 6)
# 4435 번째 crew shape : (2, 6)
# 4436 번째 crew shape : (2, 6)
# 4441 번째 crew shape : (2, 6)
# 4444 번째 crew shape : (2, 6)
# 4446 번째 crew shape : (2, 6)
# 4451 번째 crew shape : (0, 0)
# 4452 번째 crew shape : (1, 6)
# 4454 번째 crew shape : (2, 6)
# 4461 번째 crew shape : (1, 6)
# 4468 번째 crew shape : (1, 6)
# 4471 번째 crew shape : (1, 6)
# 4477 번째 crew shape : (1, 6)
# 4483 번째 crew shape : (1, 6)
# 4484 번째 crew shape : (1, 6)
# 4486 번째 crew shape : (1, 6)
# 4492 번째 crew shape : (1, 6)
# 4494 번째 crew shape : (1, 6)
# 4497 번째 crew shape : (0, 0)
# 4501 번째 crew shape : (1, 6)
# 4506 번째 crew shape : (1, 6)
# 4510 번째 crew shape : (2, 6)
# 4512 번째 crew shape : (1, 6)
# 4515 번째 crew shape : (2, 6)
# 4517 번째 crew shape : (2, 6)
# 4518 번째 crew shape : (2, 6)
# 4519 번째 crew shape : (1, 6)
# 4522 번째 crew shape : (2, 6)
# 4524 번째 crew shape : (1, 6)
# 4533 번째 crew shape : (1, 6)
# 4540 번째 crew shape : (1, 6)
# 4543 번째 crew shape : (1, 6)
# 4544 번째 crew shape : (2, 6)
# 4546 번째 crew shape : (0, 0)
# 4550 번째 crew shape : (1, 6)
# 4555 번째 crew shape : (0, 0)
# 4557 번째 crew shape : (1, 6)
# 4559 번째 crew shape : (0, 0)
# 4560 번째 crew shape : (2, 6)
# 4562 번째 crew shape : (2, 6)
# 4564 번째 crew shape : (0, 0)
# 4565 번째 crew shape : (2, 6)
# 4567 번째 crew shape : (1, 6)
# 4574 번째 crew shape : (1, 6)
# 4576 번째 crew shape : (0, 0)
# 4577 번째 crew shape : (2, 6)
# 4582 번째 crew shape : (0, 0)
# 4583 번째 crew shape : (2, 6)
# 4586 번째 crew shape : (1, 6)
# 4593 번째 crew shape : (1, 6)
# 4600 번째 crew shape : (1, 6)
# 4604 번째 crew shape : (1, 6)
# 4607 번째 crew shape : (2, 6)
# 4610 번째 crew shape : (1, 6)
# 4613 번째 crew shape : (2, 6)
# 4614 번째 crew shape : (2, 6)
# 4618 번째 crew shape : (1, 6)
# 4625 번째 crew shape : (2, 6)
# 4626 번째 crew shape : (0, 0)
# 4627 번째 crew shape : (1, 6)
# 4628 번째 crew shape : (1, 6)
# 4629 번째 crew shape : (2, 6)
# 4631 번째 crew shape : (0, 0)
# 4634 번째 crew shape : (2, 6)
# 4637 번째 crew shape : (0, 0)
# 4639 번째 crew shape : (2, 6)
# 4641 번째 crew shape : (2, 6)
# 4644 번째 crew shape : (2, 6)
# 4646 번째 crew shape : (2, 6)
# 4650 번째 crew shape : (0, 0)
# 4651 번째 crew shape : (1, 6)
# 4655 번째 crew shape : (0, 0)
# 4656 번째 crew shape : (2, 6)
# 4659 번째 crew shape : (2, 6)
# 4660 번째 crew shape : (1, 6)
# 4661 번째 crew shape : (1, 6)
# 4667 번째 crew shape : (0, 0)
# 4668 번째 crew shape : (2, 6)
# 4670 번째 crew shape : (2, 6)
# 4672 번째 crew shape : (1, 6)
# 4673 번째 crew shape : (2, 6)
# 4674 번째 crew shape : (2, 6)
# 4675 번째 crew shape : (2, 6)
# 4677 번째 crew shape : (2, 6)
# 4678 번째 crew shape : (1, 6)
# 4682 번째 crew shape : (2, 6)
# 4683 번째 crew shape : (2, 6)
# 4688 번째 crew shape : (2, 6)
# 4695 번째 crew shape : (1, 6)
# 4699 번째 crew shape : (1, 6)
# 4702 번째 crew shape : (2, 6)
# 4703 번째 crew shape : (1, 6)
# 4705 번째 crew shape : (2, 6)
# 4707 번째 crew shape : (1, 6)
# 4709 번째 crew shape : (0, 0)
# 4714 번째 crew shape : (1, 6)
# 4715 번째 crew shape : (2, 6)
# 4720 번째 crew shape : (2, 6)
# 4721 번째 crew shape : (2, 6)
# 4728 번째 crew shape : (2, 6)
# 4730 번째 crew shape : (1, 6)
# 4732 번째 crew shape : (1, 6)
# 4746 번째 crew shape : (2, 6)
# 4747 번째 crew shape : (2, 6)
# 4748 번째 crew shape : (1, 6)
# 4754 번째 crew shape : (1, 6)
# 4756 번째 crew shape : (1, 6)
# 4758 번째 crew shape : (1, 6)
# 4762 번째 crew shape : (1, 6)
# 4763 번째 crew shape : (2, 6)
# 4764 번째 crew shape : (2, 6)
# 4770 번째 crew shape : (2, 6)
# 4772 번째 crew shape : (2, 6)
# 4780 번째 crew shape : (2, 6)
# 4782 번째 crew shape : (2, 6)
# 4783 번째 crew shape : (2, 6)
# 4785 번째 crew shape : (2, 6)
# 4790 번째 crew shape : (2, 6)
# 4794 번째 crew shape : (2, 6)

# %%
def get_crews(x: pd.Series):
    ## x는 movieDF의 한 행(Series)
    if not isinstance(x, pd.Series):
        return ""
    
    crewDF = str_to_df(x['crew'])
    if crewDF.shape[0] == 0:
        ## 연출진 정보가 없다면 빈 문자열 반환
        return ""
    
    mask1 = crewDF['job'] == 'Director'
    directorList = [director for director in crewDF[mask1].name]
    
    mask2 = crewDF['job'].isin(['Writer', 'Producer', 'Screenplay', 'Executive Producer'])
    mask3 = crewDF['name'].isin(directorList)
    crewDF = crewDF[mask2 & ~mask3]             # 감독을 제외한 나머지 연출진들
    crewDF.drop_duplicates(subset=['name'], inplace=True)   # 중복된 인물 제거
    
    crew_num = len(directorList) + crewDF.shape[0]
    
    if crew_num <= 3:
        ## 다 합쳐서 3명 이하일 경우 전체 반환
        directorList = [director.lower().replace(" ", "") for director in directorList]
        crewList = [name.lower().replace(" ", "") for name in crewDF['name']]
        return " ".join(directorList + crewList)
    
    ## 다 합쳐서 3명 보다 많을 경우 (감독 + 작가 1~2명 + 제작자 1~2명)
    crewDF.drop_duplicates(subset=['job'], inplace=True)
    directorList = [director.lower().replace(" ", "") for director in directorList]
    crewList = [name.lower().replace(" ", "") for name in crewDF['name']]
    return " ".join(directorList + crewList)

# %%
str_to_df(movieDF.loc[4661, 'crew'])
# Out:
#                   credit_id department  gender      id       job  \
# 0  52fe47fbc3a368484e0e3c1f  Directing       0  558559  Director
#
#               name
# 0  Al Silliman Jr.

# %%
get_crews(movieDF.iloc[4661])
# Out:
# 'alsillimanjr.'

# %%
### 주요 출연진, 연출진 목록 저장
movieDF['credit'] = movieDF.apply(lambda x: get_casts(x) + ' ' + get_crews(x), axis=1)

# %%
movieDF.loc[3, 'credit']
# Out:
# 'christianbale michaelcaine garyoldman christophernolan charlesroven jonathannolan michaeluslan'

# %%
### TF-IDF 행렬 생성 (=> 12642 단어[=인물명] 존재)
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix2 = tfidf.fit_transform(movieDF['credit']) # scipy.sparse._csr.csr_matrix
print(f'TF-IDF 행렬의 크기(shape) : {tfidf_matrix2.shape}')
# Out:
# TF-IDF 행렬의 크기(shape) : (4796, 12642)

# %%
### 메모리 부족 주의 !!! (MemoryError 주의)
cosine_sim2 = cosine_similarity(tfidf_matrix2, tfidf_matrix2)  # ndarray
print(f'코사인 유사도 연산 결과 : {cosine_sim2.shape}')
# Out:
# 코사인 유사도 연산 결과 : (4796, 4796)

# %%
get_recommendations('The Dark Knight Rises', cosine_sim2)
# Out:
# 65                         The Dark Knight
# 1196                          The Prestige
# 119                          Batman Begins
# 95                            Interstellar
# 9       Batman v Superman: Dawn of Justice
# 1149                       American Hustle
# 3171                         The Contender
# 1600                      Secondhand Lions
# 60                       A Christmas Carol
# 299                         Batman Forever
# Name: title, dtype: object

# %%
get_recommendations('The Dark Knight Rises', cosine_sim2, True)
# Out:
# [65, 1196, 119, 95, 9, 1149, 3171, 1600, 60, 299]

# %%
### 코사인 유사도 행렬(ndarray)을 csv 파일로 저장 (548MB)
# np.savetxt('../data/processed/cosine_similarity2_4796.csv', cosine_sim2, delimiter=',')

# %%
### 코사인 유사도 행렬(ndarray)을 npy 파일로 저장 (175MB)
np.save('../data/processed/cosine_similarity2_4796.npy', cosine_sim2)
